# %% [markdown]
# The murder of Roger Ackroyd by Agatha Christie
#
# Source https://www.gutenberg.org/ebooks/69087
#
# Ref https://en.wikipedia.org/wiki/The_Murder_of_Roger_Ackroyd

# %%
# Concept art

Summary: 

Genre: 

Background: 

Main charactor:

Prompt:
Main charactor + Background + Summary
--ar 3:2 --no text
    
19th century, United Kingdom, in the room of wealthy house,
 a close-up of a hand holding a letter opener or a knife, with a shadowy figure in the background. The hand could be partially obscured by a veil or mist, adding to the sense of mystery and suspense. 
 The background could be a dark and shadowy scene,
--ar 3:2 --no text
  
19th century, United Kingdom, in the room of wealthy house,
 a close-up of a knife, with a shadowy figure in the background. with sense of mystery and suspense. 
 The background is a dark and shadowy scene.
--ar 3:2 --no text
    
19th century, United Kingdom, in the room of wealthy house,
a retired detective, looking thoughtful, with a magnifying glass in hand. 
 The background could be a dark and shadowy scene, , adding to the sense of mystery and suspense.
 --ar 3:2 --no text   
    
19th century, United Kingdom, 
a retired detective, His head the shape of an egg, His moustache was very stiff and military,
The neatness of his attire was almost incredible,
searching in in the room of wealthy house, with a magnifying glass in hand, looking thoughtful
The background is dark and shadowy scene, , adding to the sense of mystery and suspense,
--ar 3:2 --no text  

19th century, United Kingdom, in the room of wealthy people house,
a close-up of a hand holding a knife, with a shadowy figure in the background,
the hand visible partially obscured by a veil or mist,
The background is dark and shadowy scene, , adding to the sense of mystery and suspense.
--ar 3:2 --no text  

19th century, United Kingdom, 
a retired detective , with a magnifying glass in hand, 
His head has shape of an egg, His moustache was very stiff and military, his attire is neat,
searching in in the room of wealthy house, looking thoughtful
The background is dark and shadowy scene, , adding to the sense of mystery and suspense.
--ar 3:2 --no text 
    
19th century, United Kingdom, 
a close-up of a knife with blood on the floor in the room of wealthy people house,
shadowy figure near by.
The background is dark and shadowy scene, , adding to the sense of mystery and suspense.
--ar 3:2 --no text

# %%
# Youtube description

Prompt: Write title, description, and keywords of youtube video of full audiobook of the classic book "The murder of Roger Ackroyd by Agatha Christie"
    
Title: The Murder of Roger Ackroyd by Agatha Christie: Full Audiobook Edition

Description: Enter the world of the Queen of Crime, Agatha Christie, with this full audiobook edition of her classic novel "The Murder of Roger Ackroyd." Follow detective Hercule Poirot as he investigates the mysterious death of a wealthy industrialist, uncovering secrets and lies in a twisting plot that will keep you guessing until the very end. Let the skilled narration and atmospheric soundscape transport you to the world of English country houses and deadly secrets.

0:00:00 Chapter 1
0:09:59 Chaptor 2
0:26:00 Chaptor 3
0:48:22 Chaptor 4
1:18:38 Chaptor 5
1:42:35 Chaptor 6
1:58:38 Chaptor 7
2:24:59 Chaptor 8
2:46:35 Chaptor 9
3:04:29 Chaptor 10
3:32:53 Chaptor 11
3:47:37 Chaptor 12
4:05:24 Chaptor 13
4:18:33 Chaptor 14
4:40:00 Chaptor 15
4:58:03 Chaptor 16
5:17:10 Chaptor 17
5:42:36 Chaptor 18
5:54:24 Chaptor 19
6:13:16 Chaptor 20
6:33:04 Chaptor 21
6:47:33 Chaptor 22
7:02:45 Chaptor 23
7:27:07 Chaptor 24
7:35:04 Chaptor 25
7:48:55 Chaptor 26
7:55:39 Chaptor 27
        
Credits
Text: Project Gutenberg https://www.gutenberg.org/ebooks/69087
Voice: Google Cloud Text-to-Speech
Produced by: The Classic Narrator 2023
    
Keywords: The Murder of Roger Ackroyd, Agatha Christie, full audiobook, classic literature, mystery, detective, Hercule Poirot, secrets, lies, English country houses, skilled narration, atmospheric soundscape, classic novel.

# %%
# Voice test

from TextToAudiobook import *
test_tta = TextToAudiobook("test")



text = '''
<speak>
I can trust him. He and Inspector Raglan will manage it between them. I
should not like Caroline to know. She is fond of me, and then, too, she
is proud.... My death will be a grief to her, but grief passes....
</speak>
'''

# Test voices
# voice = texttospeech.VoiceSelectionParams(
#     language_code="en-GB",
#     name="en-GB-Neural2-A",
# )

voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Neural2-D",
)


audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)

test_tta.synthesize_ssml(text, "output.mp3", voice, audio_config)
# test_tta.synthesize_text(text, "output.mp3", voice, audio_config)
# Out:
# Generate audio => output.mp3
# 1

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
# Text to script

from TextToAudiobook import *

folder_name = "TheMurderofRogerAckroyd"
file_name = "69087-1.txt"

test_tta = TextToAudiobook(folder_name, char_limit_per_call=1000)

# %%
#1 Clean raw file and copy to clean folder
print(test_tta.clean_txt_raw(file_name))

#2 Tag speech in clean file and copy to tag folder
print(test_tta.tag_txt_clean(file_name))

#3 Mark break point by chapter and characters limit
print(test_tta.break_txt_tag(file_name))

#4 Split into files by chapter and characters break
print(test_tta.split_txt_break(file_name))
# Out:
# Clean: 10367 lines
# ./TheMurderofRogerAckroyd/project_file/clean/69087-1.txt
# Tag: 10367 lines
# ./TheMurderofRogerAckroyd/project_file/tag/69087-1.txt
# Break: 10367 lines
# ./TheMurderofRogerAckroyd/project_file/break/69087-1.txt
# Split: 505 files
# ./TheMurderofRogerAckroyd/project_file/split/69087-1_txt/

# %%
# Split into files by chapter and characters break
voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Neural2-D",
)

audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)
print(test_tta.synthesize_txt_split(file_name, file_limit=200, voice=voice, audio_config=audio_config))
# Out:
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_009.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_010.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_011.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_012.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_013.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_014.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_015.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_016.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_017.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_018.mp3
# Generate audio => ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/0015_019.mp3
# ...

# %%
# Merge audio files => full length
print(test_tta.merge_audio_files(file_name))
# Out:
# Generate track list: ./TheMurderofRogerAckroyd/project_file/audio/69087-1_txt/track_list.txt [total: 505 files]
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
# Audio + Image => Video
print(test_tta.merge_video_file(file_name))
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
print(test_tta.gen_youtube_chapter_marker(file_name))
# Out:
# 0:00:00 Chapter 1
# 0:09:59 Chaptor 2
# 0:26:00 Chaptor 3
# 0:48:22 Chaptor 4
# 1:18:38 Chaptor 5
# 1:42:35 Chaptor 6
# 1:58:38 Chaptor 7
# 2:24:59 Chaptor 8
# 2:46:35 Chaptor 9
# 3:04:29 Chaptor 10
# 3:32:53 Chaptor 11
# 3:47:37 Chaptor 12
# 4:05:24 Chaptor 13
# 4:18:33 Chaptor 14
# 4:40:00 Chaptor 15
# 4:58:03 Chaptor 16
# 5:17:10 Chaptor 17
# 5:42:36 Chaptor 18
# 5:54:24 Chaptor 19
# 6:13:16 Chaptor 20
# 6:33:04 Chaptor 21
# 6:47:33 Chaptor 22
# 7:02:45 Chaptor 23
# 7:27:07 Chaptor 24
# 7:35:04 Chaptor 25
# 7:48:55 Chaptor 26
# 7:55:39 Chaptor 27
