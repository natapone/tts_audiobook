7:19:04 Chaptor 31
7:30:24 Chaptor 32
7:44:05 Chaptor 33
7:56:39 Chaptor 34
8:03:32 Chaptor 35
8:13:55 Chaptor 36
8:25:07 Chaptor 37
8:43:46 Chaptor 38
9:00:55 Chaptor 39
        
Credits
Text: Project Gutenberg https://www.gutenberg.org/ebooks/2895
Voice: Google Cloud Text-to-Speech
Produced by: The Classic Narrator 2023

# %%
Title: Following the Equator by Mark Twain: Full Audiobook - Part 2/2

Sit back, relax and let us take you on a journey around the world with Mark Twain's classic travelogue, "Following the Equator". 
    Join the iconic American author on his adventures as he sails across oceans, explores exotic lands, and shares his wry observations and humorous anecdotes. 
    This full audiobook is perfect for those who love classic literature and travel writing.

0:00:00 Chaptor 40
0:14:40 Chaptor 41
0:28:35 Chaptor 42
0:40:16 Chaptor 43
1:01:50 Chaptor 44
1:15:18 Chaptor 45
1:36:18 Chaptor 46
1:58:49 Chaptor 47
2:20:13 Chaptor 48
2:38:49 Chaptor 49
3:04:53 Chaptor 50
3:21:57 Chaptor 51
3:38:10 Chaptor 52
3:57:38 Chaptor 53
4:15:31 Chaptor 54
4:31:09 Chaptor 55
4:48:21 Chaptor 56
5:00:14 Chaptor 57
5:41:05 Chaptor 58
6:11:32 Chaptor 59
6:37:49 Chaptor 60
6:58:13 Chaptor 61
7:19:32 Chaptor 62
7:41:17 Chaptor 63
7:58:49 Chaptor 64
8:17:23 Chaptor 65
8:33:09 Chaptor 66
8:59:24 Chaptor 67
9:27:05 Chaptor 68
9:51:37 Chaptor 69
        
Credits
Text: Project Gutenberg https://www.gutenberg.org/ebooks/2895
Voice: Google Cloud Text-to-Speech
Produced by: The Classic Narrator 2023
    
Keywords: Mark Twain, Following the Equator, travelogue, audiobook, full audiobook, classic literature, travel writing, journey around the world, exotic lands, observations, humorous

# %%
# Voice test

from TextToAudiobook import *
test_tta = TextToAudiobook("test")



text = '''

xxxx

'''

# Test voices
voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Neural2-A",
)

voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Standard-A",
)


audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)

test_tta.synthesize_ssml(text, "output.mp3", voice, audio_config)
# test_tta.synthesize_text(text, "output.mp3", voice, audio_config)

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
# Text to script

from TextToAudiobook import *

folder_name = "FollowingTheEquator"
file_name = "2895-1.txt"

test_tta = TextToAudiobook(folder_name, char_limit_per_call=2000)

# %%
#1 Clean raw file and copy to clean folder
print(test_tta.clean_txt_raw(file_name))

#2 Tag speech in clean file and copy to tag folder
print(test_tta.tag_txt_clean(file_name))

#3 Mark break point by chapter and characters limit
print(test_tta.break_txt_tag(file_name))

#4 Split into files by chapter and characters break
print(test_tta.split_txt_break(file_name))
# Out:
# Clean: 18626 lines
# ./FollowingTheEquator/project_file/clean/2895-1.txt
# Tag: 18626 lines
# ./FollowingTheEquator/project_file/tag/2895-1.txt
# Break: 18626 lines
# ./FollowingTheEquator/project_file/break/2895-1.txt
# Split: 582 files
# ./FollowingTheEquator/project_file/split/2895-1_txt/

# %%
# Split into files by chapter and characters break - part 1
file_name = "2895-1.txt"
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US",
    name="en-US-Standard-C",
)

audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)
print(test_tta.synthesize_txt_split(file_name, file_limit=100, voice=voice, audio_config=audio_config))
# Out:
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0026_006.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_001.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_002.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_003.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_004.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_005.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_006.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_007.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_008.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_009.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-1_txt/0027_010.mp3
# ...

# %%
# part 2
file_name = "2895-2.txt"

voice = texttospeech.VoiceSelectionParams(
    language_code="en-US",
    name="en-US-Standard-C",
)

audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)
print(test_tta.synthesize_txt_split(file_name, file_limit=200, voice=voice, audio_config=audio_config))
# Out:
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_004.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_005.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_006.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_007.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_008.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_009.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_010.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0060_011.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0061_001.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0061_002.mp3
# Generate audio => ./FollowingTheEquator/project_file/audio/2895-2_txt/0061_003.mp3
# ...

# %%
# Merge audio files => full length - part 1
file_name = "2895-1.txt"
print(test_tta.merge_audio_files(file_name))
# Out:
# Generate track list: ./FollowingTheEquator/project_file/audio/2895-1_txt/track_list.txt [total: 294 files]
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
# Merge audio files => full length - part 2
file_name = "2895-2.txt"
print(test_tta.merge_audio_files(file_name))
# Out:
# Generate track list: ./FollowingTheEquator/project_file/audio/2895-2_txt/track_list.txt [total: 316 files]
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
# Audio + Image => Video - part 1
file_name = "2895-1.txt"
print(test_tta.merge_video_file(file_name))
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
# Audio + Image => Video - part 2
file_name = "2895-2.txt"
print(test_tta.merge_video_file(file_name))
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
file_name = "2895-1.txt"
print(test_tta.gen_youtube_chapter_marker(file_name))
# Out:
# 0:00:00 Chapter 1
# 0:16:39 Chaptor 2
# 0:44:12 Chaptor 3
# 1:11:10 Chaptor 4
# 1:29:07 Chaptor 5
# 1:40:57 Chaptor 6
# 1:57:13 Chaptor 7
# 2:10:14 Chaptor 8
# 2:25:36 Chaptor 9
# 2:44:12 Chaptor 10
# 2:52:30 Chaptor 11
# 3:03:09 Chaptor 12
# 3:12:16 Chaptor 13
# 3:31:33 Chaptor 14
# 3:40:24 Chaptor 15
# 3:50:04 Chaptor 16
# 4:02:39 Chaptor 17
# 4:12:12 Chaptor 18
# 4:27:34 Chaptor 19
# 4:41:32 Chaptor 20
# 4:53:17 Chaptor 21
# 5:09:33 Chaptor 22
# 5:26:44 Chaptor 23
# 5:39:18 Chaptor 24
# 5:53:20 Chaptor 25
# 6:11:23 Chaptor 26
# 6:22:32 Chaptor 27
# 6:42:13 Chaptor 28
# 6:57:15 Chaptor 29
# 7:09:50 Chaptor 30
# 7:19:04 Chaptor 31
# 7:30:24 Chaptor 32
# 7:44:05 Chaptor 33
# 7:56:39 Chaptor 34
# 8:03:32 Chaptor 35
# 8:13:55 Chaptor 36
# 8:25:07 Chaptor 37
# 8:43:46 Chaptor 38
# 9:00:55 Chaptor 39

# %%
file_name = "2895-2.txt"
print(test_tta.gen_youtube_chapter_marker(file_name))
# Out:
# 0:00:00 Chapter 1
# 0:00:00 Chaptor 40
# 0:14:40 Chaptor 41
# 0:28:35 Chaptor 42
# 0:40:16 Chaptor 43
# 1:01:50 Chaptor 44
# 1:15:18 Chaptor 45
# 1:36:18 Chaptor 46
# 1:58:49 Chaptor 47
# 2:20:13 Chaptor 48
# 2:38:49 Chaptor 49
# 3:04:53 Chaptor 50
# 3:21:57 Chaptor 51
# 3:38:10 Chaptor 52
# 3:57:38 Chaptor 53
# 4:15:31 Chaptor 54
# 4:31:09 Chaptor 55
# 4:48:21 Chaptor 56
# 5:00:14 Chaptor 57
# 5:41:05 Chaptor 58
# 6:11:32 Chaptor 59
# 6:37:49 Chaptor 60
# 6:58:13 Chaptor 61
# 7:19:32 Chaptor 62
# 7:41:17 Chaptor 63
# 7:58:49 Chaptor 64
# 8:17:23 Chaptor 65
# 8:33:09 Chaptor 66
# 8:59:24 Chaptor 67
# 9:27:05 Chaptor 68
# 9:51:37 Chaptor 69
