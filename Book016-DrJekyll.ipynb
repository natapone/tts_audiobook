# %% [markdown]
# The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson
#
# Source https://www.gutenberg.org/ebooks/43
#
# Ref https://en.wikipedia.org/wiki/00

# %%
# Concept art

Summary: 

Genre: 

Background: 

Main charactor:

Prompt:
Main charactor + Background + Summary
--ar 3:2 --no text

    
ChatGPT prompt:
As image prompt generator, write prompt to generate cover image of book 'The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson'    
- Suggest the cover image
- list keys elements of the image
- explain each element in short
- add visual detail if main character
- add era of the story
- generate prompt from explanations above with comma separated

As image prompt generator, write prompt to generate cover image of book 'The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson'    
- Suggest the cover image
- list keys elements of the image
- explain each element in detail
- add visual detail if main character
- add era of the story
- generate prompt from explanations above with comma separated

Create an image of a split man, one side showing a respectable-looking man wearing a top hat and carrying a cane, 
evoking the fashion of the Victorian era, and the other side showing a twisted and monstrous version of him with a wild and unkempt appearance. 
The split man is set against a blurred and ominous background.
--ar 3:2 --no text

A split image of a well-dressed gentleman on one side, and a wild, twisted figure on the other, set against a blurred and ominous background. The gentleman has a top hat, monocle, and well-manicured mustache, while the twisted figure has gnarled teeth, pointed ears, and a hunchback.
--ar 3:2 --no text
    
    
Create an image of a split man, a well-dressed gentleman on one side, and a wild, twisted figure on the other, set against a blurred and ominous background. The gentleman has a top hat, monocle, and well-manicured mustache, while the twisted figure has gnarled teeth, pointed ears, and a hunchback.
--ar 3:2 --no text
    
a split image of a well-dressed gentleman on one side and a twisted figure on the other side, set against a blurred and ominous background. The gentleman should wear a top hat, monocle, and well-manicured mustache, while the twisted figure should have gnarled teeth, pointed ears, and a hunchback. The cover image should reflect the Victorian era
--ar 3:2 --no text
    
A well-dressed gentleman stands on one side of the image, while a twisted figure looms behind him like a shadow. The gentleman wears a top hat, monocle, and has a well-manicured mustache, while the twisted figure has gnarled teeth, pointed ears, and a hunchback. The background is blurred and ominous, hinting at the darker themes of the story.
--ar 3:2 --no text

# %%
# Youtube description

Prompt: Write title, description, and keywords of youtube video of full audiobook of the classic book "The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson"
    
Title: The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson: Full Audiobook Edition

Description: Enter the mysterious and chilling world of Robert Louis Stevenson with this full audiobook edition of his classic tale "The Strange Case of Dr. Jekyll and Mr. Hyde." Follow lawyer Gabriel John Utterson as he investigates the bizarre and sinister relationship between the respected Dr. Jekyll and the terrifying Mr. Hyde. Let the expert narration and haunting soundscape transport you to the dark streets and alleyways of Victorian London.

0:00:00 Chapter 1
0:15:04 Chaptor 2
0:34:09 Chaptor 3
0:39:15 Chaptor 4
0:49:53 Chaptor 5
1:00:35 Chaptor 6
1:10:03 Chaptor 7
1:13:39 Chaptor 8
1:41:54 Chaptor 9
1:59:28 Chaptor 10
        
Credits
Text: Project Gutenberg https://www.gutenberg.org/ebooks/43
Voice: Google Cloud Text-to-Speech
Produced by: The Classic Narrator 2023
    
Keywords: The Strange Case of Dr. Jekyll and Mr. Hyde, Robert Louis Stevenson, full audiobook, classic literature, mystery, thriller, Gabriel John Utterson, Dr. Jekyll, Mr. Hyde, Victorian London, expert narration, haunting soundscape, classic tale

# %%
# Voice test

from TextToAudiobook import *
test_tta = TextToAudiobook("test")



text = '''

xxxx

'''

# Test voices
voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Neural2-A",
)

voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Standard-A",
)


audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)

test_tta.synthesize_ssml(text, "output.mp3", voice, audio_config)
# test_tta.synthesize_text(text, "output.mp3", voice, audio_config)

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
# Text to script

from TextToAudiobook import *

folder_name = "DrJekyll"
file_name = "43-1.txt"

test_tta = TextToAudiobook(folder_name, char_limit_per_call=1000)

# %%
#1 Clean raw file and copy to clean folder
print(test_tta.clean_txt_raw(file_name))

#2 Tag speech in clean file and copy to tag folder
print(test_tta.tag_txt_clean(file_name))

#3 Mark break point by chapter and characters limit
print(test_tta.break_txt_tag(file_name))

#4 Split into files by chapter and characters break
print(test_tta.split_txt_break(file_name))
# Out:
# Clean: 2546 lines
# ./DrJekyll/project_file/clean/43-1.txt
# Tag: 2546 lines
# ./DrJekyll/project_file/tag/43-1.txt
# Break: 2546 lines
# ./DrJekyll/project_file/break/43-1.txt
# Split: 159 files
# ./DrJekyll/project_file/split/43-1_txt/

# %%
# Split into files by chapter and characters break
voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Neural2-D",
)

audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)
print(test_tta.synthesize_txt_split(file_name, file_limit=100, voice=voice, audio_config=audio_config))
# Out:
# Generate audio => ./DrJekyll/project_file/audio/43-1_txt/0010_037.mp3
# Generate audio => ./DrJekyll/project_file/audio/43-1_txt/0010_038.mp3
# Generate audio => ./DrJekyll/project_file/audio/43-1_txt/0010_039.mp3
# Synthesize: 3 files
# ./DrJekyll/project_file/audio/43-1_txt/

# %%
# Merge audio files => full length
print(test_tta.merge_audio_files(file_name))
# Out:
# Generate track list: ./DrJekyll/project_file/audio/43-1_txt/track_list.txt [total: 159 files]
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
# Audio + Image => Video
print(test_tta.merge_video_file(file_name))
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
print(test_tta.gen_youtube_chapter_marker(file_name))
# Out:
# 0:00:00 Chapter 1
# 0:15:04 Chaptor 2
# 0:34:09 Chaptor 3
# 0:39:15 Chaptor 4
# 0:49:53 Chaptor 5
# 1:00:35 Chaptor 6
# 1:10:03 Chaptor 7
# 1:13:39 Chaptor 8
# 1:41:54 Chaptor 9
# 1:59:28 Chaptor 10
