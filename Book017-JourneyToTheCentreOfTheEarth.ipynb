# %% [markdown]
# A Journey to the Centre of the Earth by Jules Verne
#
# Source https://www.gutenberg.org/ebooks/18857
#
# Ref https://en.wikipedia.org/wiki/Journey_to_the_Center_of_the_Earth

# %%
# Concept art

Summary: 

Genre: 

Background: 

Main charactor:

Prompt:
Main charactor + Background + Summary
--ar 3:2 --no text

=== GPT4 ===
As image prompt generator, write prompt to generate cover image of book 'xxx' following steps below
- Suggest 5 options of the cover images, wait for me to confirm
- Suggest art style eg classic art, ultra-realistic, photorealism, cartoon, japanese anime, classic movie, classic photo, illustration, black and white and others as you see fit , wait for me to confirm
- Suggest composition eg cinematic still, close up short, close up short, full body short, landscape and others as you see fit , wait for me to confirm
- list keys elements of the image to explain scene / subject / action / setting, at least should include: era, main character, scene, evant detail, location, time of the day, atmosphere and others as you see fit
- explain each element in detail according to choices above
- Do not use charactors name, describe them by their visual instead
- wait for feedback and confirm before continue to next step
- generate prompt from explanations above start from art style, composition, era and all elements above in full detail with comma separated
- end with ' use Midjourney v5,  --ar 16:9 --no text'


====

An ultra-realistic cinematic still of a group of explorers making their way towards a volcano at sunset, as seen from the back. The image should show the silhouettes of the explorers against the backdrop of the glowing volcano, with warm, orange tones lighting the scene and dark clouds in the sky to create an ominous atmosphere. The explorers should be depicted as a group of five, with the main character leading the way. He wears a leather jacket with a high collar and a leather cap, and carries a backpack with ropes and other gear. The rest of the group wears similar outfits, with jackets and backpacks, and they carry various tools and equipment.

The volcano should be depicted as imposing and dangerous, with smoke and steam rising from its crater. The scene should convey a sense of adventure and danger, with the explorers on a perilous journey into the unknown.

The era should be Victorian period (1860s). Use Midjourney v5, --ar 16:9 --no text.

# %%
# Youtube description

Prompt: Write title, description, and keywords of youtube video of full audiobook of the classic book "A Journey to the Centre of the Earth by Jules Verne"
    
Title: A Journey to the Centre of the Earth Full Audiobook by Jules Verne

Description: Join us on an epic adventure as we explore the depths of the Earth in Jules Verne's classic novel, "A Journey to the Centre of the Earth." This full audiobook is narrated by a professional voice actor, bringing the story to life with vivid descriptions and engaging dialogue. Sit back, relax, and immerse yourself in one of the greatest works of science fiction of all time.

0:00:00 Chapter 1
0:12:47 Chaptor 2
0:20:52 Chaptor 3
0:37:06 Chaptor 4
0:45:08 Chaptor 5
0:53:02 Chaptor 6
1:06:47 Chaptor 7
1:15:29 Chaptor 8
1:30:44 Chaptor 9
1:43:16 Chaptor 10
1:55:09 Chaptor 11
2:08:33 Chaptor 12
2:24:48 Chaptor 13
2:39:44 Chaptor 14
2:51:46 Chaptor 15
3:03:32 Chaptor 16
3:15:32 Chaptor 17
3:27:37 Chaptor 18
3:39:01 Chaptor 19
3:46:22 Chaptor 20
3:58:26 Chaptor 21
4:07:01 Chaptor 22
4:17:49 Chaptor 23
4:25:18 Chaptor 24
4:35:17 Chaptor 25
4:49:21 Chaptor 26
4:58:56 Chaptor 27
5:15:41 Chaptor 28
5:28:34 Chaptor 29
5:46:56 Chaptor 30
6:06:34 Chaptor 31
6:18:35 Chaptor 32
6:33:07 Chaptor 33
6:49:17 Chaptor 34
7:00:54 Chaptor 35
7:15:40 Chaptor 36
7:24:53 Chaptor 37
7:32:45 Chaptor 38
7:46:39 Chaptor 39
8:00:00 Chaptor 40
8:13:57 Chaptor 41
8:28:28 Chaptor 42
8:48:07 Chaptor 43
9:00:52 Chaptor 44
        
Credits
Text: Project Gutenberg https://www.gutenberg.org/ebooks/18857
Voice: Google Cloud Text-to-Speech
Produced by: The Classic Narrator 2023
    
Keywords: Jules Verne, A Journey to the Centre of the Earth, audiobook, full, classic, novel, science fiction, adventure, exploration, narration, voice actor, listen, story, epic, depths of the Earth.

# %%
# Voice test

from TextToAudiobook import *
test_tta = TextToAudiobook("test")



text = '''

xxxx

'''

# Test voices
voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Neural2-A",
)

voice = texttospeech.VoiceSelectionParams(
    language_code="en-GB",
    name="en-GB-Standard-A",
)


audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.9
)

test_tta.synthesize_ssml(text, "output.mp3", voice, audio_config)
# test_tta.synthesize_text(text, "output.mp3", voice, audio_config)

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
# Text to script

from TextToAudiobook import *

folder_name = "JourneyToTheCentreOfTheEarth"
file_name = "18857-1.txt"

test_tta = TextToAudiobook(folder_name, char_limit_per_call=1000)

# %%
#1 Clean raw file and copy to clean folder
print(test_tta.clean_txt_raw(file_name))

#2 Tag speech in clean file and copy to tag folder
print(test_tta.tag_txt_clean(file_name))

#3 Mark break point by chapter and characters limit
print(test_tta.break_txt_tag(file_name))

#4 Split into files by chapter and characters break
print(test_tta.split_txt_break(file_name))
# Out:
# Clean: 10825 lines
# ./JourneyToTheCentreOfTheEarth/project_file/clean/18857-1.txt
# Tag: 10825 lines
# ./JourneyToTheCentreOfTheEarth/project_file/tag/18857-1.txt
# Break: 10825 lines
# ./JourneyToTheCentreOfTheEarth/project_file/break/18857-1.txt
# Split: 577 files
# ./JourneyToTheCentreOfTheEarth/project_file/split/18857-1_txt/

# %%
# Split into files by chapter and characters break
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US",
    name="en-US-Neural2-H",
)

audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    speaking_rate=0.85
)
print(test_tta.synthesize_txt_split(file_name, file_limit=100, voice=voice, audio_config=audio_config))
# Out:
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_007.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_008.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_009.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_010.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_011.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_012.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_013.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_014.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_015.mp3
# Generate audio => ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/0042_016.mp3
# ...

# %%
# Merge audio files => full length
print(test_tta.merge_audio_files(file_name))
# Out:
# Generate track list: ./JourneyToTheCentreOfTheEarth/project_file/audio/18857-1_txt/track_list.txt [total: 577 files]
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
# Audio + Image => Video
print(test_tta.merge_video_file(file_name))
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.102)
# ...

# %%
print(test_tta.gen_youtube_chapter_marker(file_name))
# Out:
# 0:00:00 Chapter 1
# 0:12:47 Chaptor 2
# 0:20:52 Chaptor 3
# 0:37:06 Chaptor 4
# 0:45:08 Chaptor 5
# 0:53:02 Chaptor 6
# 1:06:47 Chaptor 7
# 1:15:29 Chaptor 8
# 1:30:44 Chaptor 9
# 1:43:16 Chaptor 10
# 1:55:09 Chaptor 11
# 2:08:33 Chaptor 12
# 2:24:48 Chaptor 13
# 2:39:44 Chaptor 14
# 2:51:46 Chaptor 15
# 3:03:32 Chaptor 16
# 3:15:32 Chaptor 17
# 3:27:37 Chaptor 18
# 3:39:01 Chaptor 19
# 3:46:22 Chaptor 20
# 3:58:26 Chaptor 21
# 4:07:01 Chaptor 22
# 4:17:49 Chaptor 23
# 4:25:18 Chaptor 24
# 4:35:17 Chaptor 25
# 4:49:21 Chaptor 26
# 4:58:56 Chaptor 27
# 5:15:41 Chaptor 28
# 5:28:34 Chaptor 29
# 5:46:56 Chaptor 30
# 6:06:34 Chaptor 31
# 6:18:35 Chaptor 32
# 6:33:07 Chaptor 33
# 6:49:17 Chaptor 34
# 7:00:54 Chaptor 35
# 7:15:40 Chaptor 36
# 7:24:53 Chaptor 37
# 7:32:45 Chaptor 38
# 7:46:39 Chaptor 39
# 8:00:00 Chaptor 40
# 8:13:57 Chaptor 41
# 8:28:28 Chaptor 42
# 8:48:07 Chaptor 43
# 9:00:52 Chaptor 44
